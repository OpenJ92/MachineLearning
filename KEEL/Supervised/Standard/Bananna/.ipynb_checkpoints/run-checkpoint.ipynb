# %%
from Load.load import Base_Load
from Load.supervised import Supervised
from Load.regression import Regression
from Load.classification import Classification
from pandas.plotting import scatter_matrix, parallel_coordinates, andrews_curves

import numpy as n
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
loadC = Classification("Data", "banana.dat", "bananna-names.txt")
loadR = Regression("Data", "banana.dat", "bananna-names.txt")
loadS = Supervised("Data", "banana.dat", "bananna-names.txt")

# %%
n.array(loadC.attributes)
# Out:
# array([['@attribute', 'At1', 'real[-3.09,2.81]'],
#        ['@attribute', 'At2', 'real[-2.39,3.19]'],
#        ['@attribute', 'Class', '{-1.0,1.0}']], dtype='<U16')

# %%
scatter_matrix(loadC.data()[loadC.inputs], diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a24b2d748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24bc14a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a24d1f5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24bada58>]],
#       dtype=object)

# %%
parallel_coordinates(loadC.data(),*loadC.outputs)

# %%
andrews_curves(loadC.data(),*loadC.outputs)
